# %% [markdown]
# # Hypervolume Convergence for MOEAD Experiments
# - Author: Renan Santos
# - Email: renansantosmendes@gmail.com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Functions to read and plot the hypervolume values

# %%
def read_data(folder):
    executions_number = 5
    df_list = []
    for i in range(executions_number):
        df = pd.read_csv(folder + 'hypervolume_execution_'+str(i)+'.csv',header=None)
        df.columns = str(i).split()
        df_list.append(df)

    return pd.concat(df_list, axis=1)

def plot_convergence(result):
    plt.figure(figsize=(10,8))
    result.mean(axis=1).plot()
    plt.show()

# %% [markdown]
# ### Convergence for DTLZ5 with 2 objectives

# %%
folder = 'DTLZ5-2/'
result = read_data(folder)
plot_convergence(result[200:])

# %%
folder = 'WFG2-2/'
result = read_data(folder)
plot_convergence(result)

# %%
folder = 'DTLZ3-2/'
result = read_data(folder)
plot_convergence(result)

# %%
folder = 'DTLZ2-2/'
result = read_data(folder)
plot_convergence(result)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-3-1daf27896f14> in <module>()
#       1 folder = 'DTLZ2-2/'
# ----> 2 result = read_data(folder)
#       3 plot_convergence(result)
#
# <ipython-input-2-9f01de005955> in read_data(folder)
#       3     df_list = []
#       4     for i in range(executions_number):
# ----> 5         df = pd.read_csv(folder + 'hypervolume_execution_'+str(i)+'.csv',header=None)
#       6         df.columns = str(i).split()
#       7         df_list.append(df)
#
# ...

# %%
### Convergence for DTLZ5 with 5 objectives

# %%
folder = 'DTLZ2-2/'
result = read_data(folder)
plot_convergence(result)

# %%
folder = 'DTLZ1-2/'
result = read_data(folder)
plot_convergence(result)

# %%
folder = 'DTLZ3-2/'
result = read_data(folder)
plot_convergence(result)

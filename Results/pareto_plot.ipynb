# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def read_data(problem):
    x = []
    y = []
    with open(problem +'/'+problem + '-solutions.csv') as file:
        for line in file:
            try:
                splitted_line = line.split('Objectives: ')[1].replace('AlgorithmAttributes: {}','')\
                    .strip().split()
                x.append(float(splitted_line[0]))
                y.append(float(splitted_line[1]))
            except:
                pass
            
    df = pd.DataFrame(data=[x,y]).T
    df.columns = 'X Y'.split()
    return df

def read_pop_ini(problem):
    x = []
    y = []
    with open(problem +'/pop_ini.csv') as file:
        for line in file:
            try:
                splitted_line = line.split('Objectives: ')[1].replace('AlgorithmAttributes: {}','')\
                    .strip().split()
                x.append(float(splitted_line[0]))
                y.append(float(splitted_line[1]))
            except:
                pass
            
    df = pd.DataFrame(data=[x,y]).T
    df.columns = 'X Y'.split()
    return df

def plot_solutions(df):
    plt.figure(figsize=(10,8))
    df.plot(kind='scatter', x= 'X', y= 'Y')
    plt.show()

# %%
problem = 'DTLZ1-2'
plot_solutions(read_data(problem))

# %%
problem = 'DTLZ2-2'
plot_solutions(read_data(problem))

# %%
problem = 'DTLZ3-2'
plot_solutions(read_data(problem))

# %%
problem = 'DTLZ4-2'
plot_solutions(read_data(problem))

# %%
problem = 'DTLZ1-2'
plot_solutions(read_data(problem))

# %%
df1 = read_pop_ini(problem)
df2 = read_data(problem)
plot_solutions(df1.append(df2).reset_index(drop=True))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-69bf141daf33> in <module>()
# ----> 1 df1 = read_pop_ini(problem)
#       2 df2 = read_data(problem)
#       3 plot_solutions(df1.append(df2).reset_index(drop=True))
#
# <ipython-input-2-2e1889aaca26> in read_pop_ini(problem)
#      18     x = []
#      19     y = []
# ---> 20     with open(problem +'/pop_ini.csv') as file:
#      21         for line in file:
#      22             try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DTLZ1-2/pop_ini.csv'

# %%
problem = 'WFG2-2'
plot_solutions(read_data(problem))

# %%
df1 = read_pop_ini(problem)
df2 = read_data(problem)
plot_solutions(df1.append(df2).reset_index(drop=True))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-69bf141daf33> in <module>()
# ----> 1 df1 = read_pop_ini(problem)
#       2 df2 = read_data(problem)
#       3 plot_solutions(df1.append(df2).reset_index(drop=True))
#
# <ipython-input-2-2e1889aaca26> in read_pop_ini(problem)
#      18     x = []
#      19     y = []
# ---> 20     with open(problem +'/pop_ini.csv') as file:
#      21         for line in file:
#      22             try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'WFG2-2/pop_ini.csv'

# %%
problem = 'DTLZ2-2'
plot_solutions(read_pop_ini(problem))

# %%
problem = 'DTLZ2-2'
df1 = read_pop_ini(problem)
df2 = read_data(problem)
plot_solutions(df1.append(df2).reset_index(drop=True))
